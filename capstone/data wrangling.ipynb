# %%
import pandas as pd
raw=pd.read_csv('diabetic_data.csv')

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
raw.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
#take one of the row 
raw.iloc[0]
# Out:
# encounter_id                                 2278392
# patient_nbr                                  8222157
# race                                       Caucasian
# gender                                        Female
# age                                           [0-10)
# weight                                             ?
# admission_type_id                                  6
# discharge_disposition_id                          25
# admission_source_id                                1
# time_in_hospital                                   1
# payer_code                                         ?
# medical_specialty           Pediatrics-Endocrinology
# num_lab_procedures                                41
# num_procedures                                     0
# num_medications                                    1
# number_outpatient                                  0
# number_emergency                                   0
# number_inpatient                                   0
# ...

# %%
raw_data = raw[(raw != '?').all(axis=1)]
# Out:
# D:\anaconda\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
raw_data = raw_data[(raw_data != 'E878').all(axis=1)]

# %%
raw_data = raw_data[(raw_data != 'V58').all(axis=1)]
raw_data = raw_data[(raw_data != 'V54').all(axis=1)]
raw_data = raw_data[(raw_data != 'V57').all(axis=1)]
raw_data = raw_data[(raw_data != 'V45').all(axis=1)]
raw_data = raw_data[(raw_data != 'V71').all(axis=1)]
raw_data = raw_data[(raw_data != 'V42').all(axis=1)]
raw_data = raw_data[(raw_data != 'V15').all(axis=1)]
raw_data = raw_data[(raw_data != 'V10').all(axis=1)]
raw_data = raw_data[(raw_data != 'V85').all(axis=1)]
raw_data = raw_data[(raw_data != 'V43').all(axis=1)]
raw_data = raw_data[(raw_data != 'V09').all(axis=1)]
raw_data = raw_data[(raw_data != 'V27').all(axis=1)]
raw_data = raw_data[(raw_data != 'V55').all(axis=1)]
raw_data = raw_data[(raw_data != 'V53').all(axis=1)]
raw_data = raw_data[(raw_data != 'V12').all(axis=1)]
raw_data = raw_data[(raw_data != 'E888').all(axis=1)]
raw_data = raw_data[(raw_data != 'E885').all(axis=1)]
raw_data = raw_data[(raw_data != 'E947').all(axis=1)]
raw_data = raw_data[(raw_data != 'E881').all(axis=1)]
raw_data = raw_data[(raw_data != 'E917').all(axis=1)]
raw_data = raw_data[(raw_data != 'E936').all(axis=1)]
raw_data = raw_data[(raw_data != 'E942').all(axis=1)]
raw_data = raw_data[(raw_data != 'E934').all(axis=1)]
raw_data = raw_data[(raw_data != 'E935').all(axis=1)]
raw_data = raw_data[(raw_data != 'E932').all(axis=1)]
raw_data = raw_data[(raw_data != 'E941').all(axis=1)]
raw_data = raw_data[(raw_data != 'E879').all(axis=1)]
raw_data = raw_data[(raw_data != 'E816').all(axis=1)]
raw_data = raw_data[(raw_data != 'E884').all(axis=1)]
raw_data = raw_data[(raw_data != 'E928').all(axis=1)]
raw_data = raw_data[(raw_data != 'E944').all(axis=1)]
raw_data = raw_data[(raw_data != 'E919').all(axis=1)]
raw_data = raw_data[(raw_data != 'E812').all(axis=1)]
raw_data = raw_data[(raw_data != 'E939').all(axis=1)]
raw_data = raw_data[(raw_data != 'E931').all(axis=1)]

# %%
raw_data
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 27068       88792836    100654011        Caucasian  Female  [70-80)
# 27128       88986678     58682736        Caucasian    Male  [80-90)
# 27147       89032962     69250302        Caucasian    Male  [60-70)
# 27186       89191392     62022042        Caucasian    Male  [40-50)
# 27236       89277516     30950811        Caucasian    Male  [50-60)
# ...              ...          ...              ...     ...      ...
# 101238     436721264    123812618  AfricanAmerican    Male  [70-80)
# 101330     437928656    117516146        Caucasian    Male  [30-40)
# 101340     437959022      8420319        Caucasian    Male  [60-70)
# 101449     439577312     97708986        Caucasian  Female  [70-80)
# 101456     439606454    113392368  AfricanAmerican    Male  [60-70)
#
#            weight  admission_type_id  discharge_disposition_id  \
# 27068    [75-100)                  3                         3
# ...

# %%
def map_values(df):
    df['race'] = df['race'].map({'Other':1,
                                             'Hispanic':2, 
                                             'Caucasian':3,  
                                             'AfricanAmerican':4 ,
                                                'Asian':5})

    df['gender'] = df['gender'].map({'Female':1, 'Male':0})

    df['weight'] = df['weight'].map({'[0-10)':1,
                                               '[10-25)':2, 
                                               '[25-50)':3, 
                                               '[50-75)':4, 
                                               '[75-100)':5, 
                                               '[100-125)':6, 
                                               '[125-150)':7,  
                                               '[150-175)':8, 
                                               '[175-200)':9,
                                               '>200':10})
    df['age'] = df['age'].map({'[0-25)':1,
                                               '[10-20)':2, 
                                               '[20-30)':3, 
                                               '[30-40)':4, 
                                               '[40-50)':5, 
                                               '[50-60)':6, 
                                               '[60-70)':7,  
                                               '[70-80)':8, 
                                               '[80-90)':9,
                                               '[90-100)':10})

    df['payer_code'] = df['payer_code'].map({'BC':1, 
                                           'CH':2, 'CM':3, 'CP':4, 
                                           'DM':5, 'FR':6,
                                           'HM':7, 'MC':8,'MD':9,'MP':10,'OG':11,'OT':12,'PO':13,'SI':14,'SP':15,'UN':16,'WC':17})

    df['medical_specialty'] = df['medical_specialty'].map({'Urology':1, 'SurgicalSpecialty':2, 
                                                             'Surgery-Vascular':3, 'Surgery-Thoracic':4,
                                                            'Surgery-PlasticwithinHeadandNeck':5,
                                                             'Surgery-Plastic':6,'Surgery-Pediatric':7,
                                                            'Surgery-Pediatric':8,'Surgery-Maxillofacial':9,
                                                            'Surgery-General':10,'Surgery-Colon&Rectal':11,
                                                            'Surgery-Cardiovascular/Thoracic':12,
                                                            'Surgery-Cardiovascular':13,'Surgeon':14,
                                                            'SportsMedicine':15,'Speech':16,'Rheumatology':17,
                                                            'Resident':18,'Radiology':19,'Radiologist':20,
                                                            'Pulmonology':21,'Psychology':22,'Psychiatry-Child/Adolescent':23,
                                                            'Psychiatry-Addictive':24,'Psychiatry':25,
                                                            'Podiatry':26,'PhysicianNotFound':27,'PhysicalMedicineandRehabilitation':28,
                                                            'Perinatology':29,'Pediatrics-Pulmonology':30,'Pediatrics-Neurology':31,
                                                            'Pediatrics-InfectiousDiseases':32,'Pediatrics-Hematology-Oncology':33,
                                                            'Pediatrics-Endocrinology':34,'Pediatrics-EmergencyMedicine':35,
                                                            'Pediatrics-CriticalCare':36,'Pediatrics-AllergyandImmunology':37,
                                                            'Pediatrics':38,'Pathology':39,'OutreachServices':40,'Otolaryngology':41,
                                                            'Osteopath':42,'Orthopedics-Reconstructive':43,'Orthopedics':44,
                                                            'Ophthalmology':45,'Oncology':46,'ObstetricsandGynecology':47,
                                                            'Obstetrics':48,'Obsterics&Gynecology-GynecologicOnco':49,
                                                            'Neurophysiology':50,'Neurology':51,'Nephrology':52,'InternalMedicine':53,
                                                            'InfectiousDiseases':54,'Hospitalist':55,'Hematology/Oncology':56,
                                                            'Hematology':57,'Gynecology':58,'Gastroenterology':59,'Family/GeneralPractice':60,
                                                            'Endocrinology-Metabolism':61,'Endocrinology':62,'Emergency/Trauma':63,
                                                            'Dermatology':64,'Dentistry':65,'DCPTEAM':66,'Cardiology-Pediatric':67,
                                                            'Cardiology':68,'Anesthesiology-Pediatric':69,'Anesthesiology':70,
                                                            'AllergyandImmunology':71})

    df['max_glu_serum'] = df['max_glu_serum'].map({'None':1, 'Norm':2, '>200':3, '>300':4})

    df['A1Cresult'] = df['A1Cresult'].map({'None':1, 'Norm':2, '>7':3, '>8':4})

    df['metformin'] = df['metformin'].map({'No':1, 'Down':2, 'Steady':2, 'Up':3})

    df['repaglinide'] = df['repaglinide'].map({'No':1, 'Steady':2, 'Up':3})

    df['nateglinide'] = df['nateglinide'].map({'No':1, 'Steady':2, 'Up':3})

    df['chlorpropamide'] = df['chlorpropamide'].map({'No':1})

    df['glimepiride'] = df['glimepiride'].map({'No':1, 'Down':2, 'Steady':3, 'Up':4})

    df['acetohexamide'] = df['acetohexamide'].map({'No':1})

    df['glipizide'] = df['glipizide'].map({'No':1, 'Down':2, 'Steady':3, 'Up':4})

    df['glyburide'] = df['glyburide'].map({'No':1, 'Down':2, 'Steady':3, 'Up':4})

    df['tolbutamide'] = df['tolbutamide'].map({'No':1})

    df['pioglitazone'] = df['pioglitazone'].map({'No':1, 'Down':2, 'Steady':3, 'Up':4})

    df['rosiglitazone'] = df['rosiglitazone'].map({'No':1, 'Down':2, 'Steady':3, 'Up':4})

    df['acarbose'] = df['acarbose'].map({'No':1, 'Steady':2, 'Up':3})

    df['miglitol'] = df['miglitol'].map({'No':1, 'Steady':2})

    df['troglitazone'] = df['troglitazone'].map({'No':1})

    df['tolazamide'] = df['tolazamide'].map({'No':1, 'Steady':2})

    df['examide'] = df['examide'].map({'No':1})

    df['citoglipton'] = df['citoglipton'].map({'No':1})
    df['insulin'] = df['insulin'].map({'No':1, 'Down':2, 'Steady':2, 'Up':2})
    df['glyburide-metformin'] = df['glyburide-metformin'].map({'No':1, 'Down':2, 'Steady':2, 'Up':2})
    df['glipizide-metformin'] = df['glipizide-metformin'].map({'No':1,'Steady':2})
    df['glimepiride-pioglitazone'] = df['glimepiride-pioglitazone'].map({'No':1,'Steady':2})
    df['metformin-rosiglitazone'] = df['metformin-rosiglitazone'].map({'No':1,'Steady':2})
    df['metformin-pioglitazone'] = df['metformin-pioglitazone'].map({'No':1,'Steady':2})
    df['change'] = df['change'].map({'No':1,'Ch':2})
    df['diabetesMed'] = df['diabetesMed'].map({'No':1,'Yes':2})
    df['readmitted'] = df['readmitted'].map({'NO':1,'>30':2,'<30':3})
map_values(raw_data)

# %%
raw_data
# Out:
#         encounter_id  patient_nbr  race  gender  age  weight  \
# 27068       88792836    100654011     3       1    8     5.0
# 27128       88986678     58682736     3       0    9     4.0
# 27147       89032962     69250302     3       0    7     6.0
# 27186       89191392     62022042     3       0    5     5.0
# 27236       89277516     30950811     3       0    6     6.0
# ...              ...          ...   ...     ...  ...     ...
# 101238     436721264    123812618     4       0    8     5.0
# 101330     437928656    117516146     3       0    4     6.0
# 101340     437959022      8420319     3       0    7     6.0
# 101449     439577312     97708986     3       1    8     4.0
# 101456     439606454    113392368     4       0    7     5.0
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 27068                   3                         3                    1
# 27128                   1                        11                    5
# ...

# %%
missing = pd.concat([raw_data.isnull().sum(), 100 * raw_data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
# Out:
#                           count         %
# encounter_id                  0  0.000000
# chlorpropamide                0  0.000000
# glimepiride                   0  0.000000
# acetohexamide                 0  0.000000
# glipizide                     0  0.000000
# glyburide                     0  0.000000
# tolbutamide                   0  0.000000
# pioglitazone                  0  0.000000
# rosiglitazone                 0  0.000000
# acarbose                      0  0.000000
# miglitol                      0  0.000000
# troglitazone                  0  0.000000
# tolazamide                    0  0.000000
# examide                       0  0.000000
# citoglipton                   0  0.000000
# insulin                       0  0.000000
# glyburide-metformin           0  0.000000
# glipizide-metformin           0  0.000000
# glimepiride-pioglitazone      0  0.000000
# metformin-rosiglitazone       0  0.000000
# metformin-pioglitazone        0  0.000000
# ...

# %%
raw_data=raw_data.dropna()

# %%
import matplotlib.pyplot as plt
raw_data.hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5);
