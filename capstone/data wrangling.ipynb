# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## 1) Check Duplicate

# %%
import pandas as pd
raw=pd.read_csv('diabetic_data.csv')

# %%
raw.shape
# Out:
# (101766, 50)

# %%
raw.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
raw['patient_nbr'].value_counts().head()
# Out:
# 88785891    40
# 43140906    28
# 23199021    23
# 1660293     23
# 88227540    23
# Name: patient_nbr, dtype: int64

# %%
raw[raw['patient_nbr']==88785891]
# Out:
#         encounter_id  patient_nbr       race  gender      age weight  \
# 38307      119039172     88785891  Caucasian  Female  [20-30)      ?
# 40252      125094312     88785891  Caucasian  Female  [20-30)      ?
# 40661      126171582     88785891  Caucasian  Female  [20-30)      ?
# 44515      137245596     88785891  Caucasian  Female  [20-30)      ?
# 45147      139425576     88785891  Caucasian  Female  [20-30)      ?
# 45986      141994242     88785891  Caucasian  Female  [20-30)      ?
# 50167      150986298     88785891  Caucasian  Female  [20-30)      ?
# 50393      151413846     88785891  Caucasian  Female  [20-30)      ?
# 50773      152188656     88785891  Caucasian  Female  [20-30)      ?
# 51519      153558456     88785891  Caucasian  Female  [20-30)      ?
# 52057      154527444     88785891  Caucasian  Female  [20-30)      ?
# 53771      157363182     88785891  Caucasian  Female  [20-30)      ?
# 54497      158500410     88785891  Caucasian  Female  [20-30)      ?
# 60263      168920160     88785891  Caucasian  Female  [20-30)      ?
# 62759      174689286     88785891  Caucasian  Female  [20-30)      ?
# 63165      175632402     88785891  Caucasian  Female  [20-30)      ?
# 65667      183194856     88785891  Caucasian  Female  [20-30)      ?
# 67968      191345028     88785891  Caucasian  Female  [20-30)      ?
# 71029      205106328     88785891  Caucasian  Female  [20-30)      ?
# 72068      210079272     88785891  Caucasian  Female  [20-30)      ?
# 74405      221588430     88785891  Caucasian  Female  [20-30)      ?
# 74876      223647786     88785891  Caucasian  Female  [20-30)      ?
# 75267      225428574     88785891  Caucasian  Female  [20-30)      ?
# 76525      230986482     88785891  Caucasian  Female  [20-30)      ?
# 76907      232655340     88785891  Caucasian  Female  [20-30)      ?
# 78355      239153370     88785891  Caucasian  Female  [20-30)      ?
# 78882      241426656     88785891  Caucasian  Female  [20-30)      ?
# 79202      242844252     88785891  Caucasian  Female  [20-30)      ?
# 79467      243967338     88785891  Caucasian  Female  [20-30)      ?
# 82693      257757342     88785891  Caucasian  Female  [20-30)      ?
# 87063      277490424     88785891  Caucasian  Female  [20-30)      ?
# 87854      281267754     88785891  Caucasian  Female  [20-30)      ?
# 88392      284109186     88785891  Caucasian  Female  [20-30)      ?
# 89964      291808098     88785891  Caucasian  Female  [20-30)      ?
# 90913      302508452     88785891  Caucasian  Female  [20-30)      ?
# 91444      309563132     88785891  Caucasian  Female  [20-30)      ?
# 97433      388509176     88785891  Caucasian  Female  [20-30)      ?
# 97732      392073212     88785891  Caucasian  Female  [20-30)      ?
# 99950      419611106     88785891  Caucasian  Female  [20-30)      ?
# 101385     438529178     88785891  Caucasian  Female  [20-30)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 38307                   1                         1                    7
# 40252                   1                         1                    7
# 40661                   1                         1                    7
# 44515                   3                         1                    7
# 45147                   1                         1                    7
# 45986                   2                         1                    7
# 50167                   2                         1                    7
# 50393                   1                         1                    7
# 50773                   2                         7                    7
# 51519                   2                         1                    7
# 52057                   2                         1                    7
# 53771                   2                         1                    7
# 54497                   2                         1                    7
# 60263                   1                         1                    7
# 62759                   1                         1                    7
# 63165                   2                         1                    7
# 65667                   1                         1                    7
# 67968                   3                         1                    7
# 71029                   2                         1                    7
# 72068                   1                         7                    7
# 74405                   2                         1                    7
# 74876                   2                         1                    7
# 75267                   2                         1                    7
# 76525                   2                         1                    7
# 76907                   2                         1                    7
# 78355                   1                         1                    7
# 78882                   1                         1                    7
# 79202                   2                         1                    7
# 79467                   2                         1                    7
# 82693                   2                         7                    7
# 87063                   1                         1                    7
# 87854                   1                         1                    7
# 88392                   1                         1                    7
# 89964                   1                         5                    7
# 90913                   2                         1                    7
# 91444                   1                         1                    7
# 97433                   2                         1                    7
# 97732                   1                         1                    7
# 99950                   2                         1                    7
# 101385                  3                         7                    4
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 38307                  1  ...          No      Up                   No
# 40252                  1  ...          No    Down                   No
# 40661                  5  ...          No      Up                   No
# 44515                  2  ...          No      Up                   No
# 45147                  2  ...          No      Up                   No
# 45986                  4  ...          No      Up                   No
# 50167                  1  ...          No      Up                   No
# 50393                  4  ...          No      Up                   No
# 50773                  1  ...          No      Up                   No
# 51519                  1  ...          No      Up                   No
# 52057                  1  ...          No      Up                   No
# 53771                  2  ...          No    Down                   No
# 54497                  3  ...          No    Down                   No
# 60263                  8  ...          No      Up                   No
# 62759                  3  ...          No      Up                   No
# 63165                  4  ...          No    Down                   No
# 65667                  2  ...          No      Up                   No
# 67968                  5  ...          No    Down                   No
# 71029                  1  ...          No      Up                   No
# 72068                  2  ...          No    Down                   No
# 74405                  1  ...          No      Up                   No
# 74876                  2  ...          No    Down                   No
# 75267                  2  ...          No    Down                   No
# 76525                  7  ...          No      Up                   No
# 76907                  4  ...          No    Down                   No
# 78355                  7  ...          No      Up                   No
# 78882                  3  ...          No      Up                   No
# 79202                  1  ...          No      Up                   No
# 79467                  1  ...          No      Up                   No
# 82693                  2  ...          No    Down                   No
# 87063                  7  ...          No    Down                   No
# 87854                  7  ...          No      Up                   No
# 88392                  3  ...          No      Up                   No
# 89964                  6  ...          No    Down                   No
# 90913                  5  ...          No      Up                   No
# 91444                  3  ...          No      Up                   No
# 97433                  5  ...          No    Down                   No
# 97732                  3  ...          No      Up                   No
# 99950                  2  ...          No      Up                   No
# 101385                 3  ...          No      No                   No
#
#         glipizide-metformin  glimepiride-pioglitazone  \
# 38307                    No                        No
# 40252                    No                        No
# 40661                    No                        No
# 44515                    No                        No
# 45147                    No                        No
# 45986                    No                        No
# 50167                    No                        No
# 50393                    No                        No
# 50773                    No                        No
# 51519                    No                        No
# 52057                    No                        No
# 53771                    No                        No
# 54497                    No                        No
# 60263                    No                        No
# 62759                    No                        No
# 63165                    No                        No
# 65667                    No                        No
# 67968                    No                        No
# 71029                    No                        No
# 72068                    No                        No
# 74405                    No                        No
# 74876                    No                        No
# 75267                    No                        No
# 76525                    No                        No
# 76907                    No                        No
# 78355                    No                        No
# 78882                    No                        No
# 79202                    No                        No
# 79467                    No                        No
# 82693                    No                        No
# 87063                    No                        No
# 87854                    No                        No
# 88392                    No                        No
# 89964                    No                        No
# 90913                    No                        No
# 91444                    No                        No
# 97433                    No                        No
# 97732                    No                        No
# 99950                    No                        No
# 101385                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone  change diabetesMed  \
# 38307                        No                      No      Ch         Yes
# 40252                        No                      No      Ch         Yes
# 40661                        No                      No      Ch         Yes
# 44515                        No                      No      Ch         Yes
# 45147                        No                      No      Ch         Yes
# 45986                        No                      No      Ch         Yes
# 50167                        No                      No      Ch         Yes
# 50393                        No                      No      Ch         Yes
# 50773                        No                      No      Ch         Yes
# 51519                        No                      No      Ch         Yes
# 52057                        No                      No      Ch         Yes
# 53771                        No                      No      Ch         Yes
# 54497                        No                      No      Ch         Yes
# 60263                        No                      No      Ch         Yes
# 62759                        No                      No      Ch         Yes
# 63165                        No                      No      Ch         Yes
# 65667                        No                      No      Ch         Yes
# 67968                        No                      No      Ch         Yes
# 71029                        No                      No      Ch         Yes
# 72068                        No                      No      Ch         Yes
# 74405                        No                      No      Ch         Yes
# 74876                        No                      No      Ch         Yes
# 75267                        No                      No      Ch         Yes
# 76525                        No                      No      Ch         Yes
# 76907                        No                      No      Ch         Yes
# 78355                        No                      No      Ch         Yes
# 78882                        No                      No      Ch         Yes
# 79202                        No                      No      Ch         Yes
# 79467                        No                      No      Ch         Yes
# 82693                        No                      No      Ch         Yes
# 87063                        No                      No      Ch         Yes
# 87854                        No                      No      Ch         Yes
# 88392                        No                      No      Ch         Yes
# 89964                        No                      No      Ch         Yes
# 90913                        No                      No      Ch         Yes
# 91444                        No                      No      Ch         Yes
# 97433                        No                      No      Ch         Yes
# 97732                        No                      No      Ch         Yes
# 99950                        No                      No      Ch         Yes
# 101385                       No                      No      No          No
#
#        readmitted
# 38307         >30
# 40252         <30
# 40661         >30
# 44515         <30
# 45147         <30
# 45986         <30
# 50167         <30
# 50393         <30
# 50773         <30
# 51519         <30
# 52057         >30
# 53771         <30
# 54497         >30
# 60263         >30
# 62759         <30
# 63165         >30
# 65667         >30
# 67968         >30
# 71029         <30
# 72068         >30
# 74405         <30
# 74876         <30
# 75267         >30
# 76525         <30
# 76907         >30
# 78355         <30
# 78882         <30
# 79202         <30
# 79467         >30
# 82693         >30
# 87063         <30
# 87854         <30
# 88392         >30
# 89964         >30
# 90913         <30
# 91444         <30
# 97433         <30
# 97732         >30
# 99950         >30
# 101385        <30
#
# [40 rows x 50 columns]

# %%
raw.drop_duplicates(subset=['patient_nbr'], keep='last')
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       1                         1                    7
# ...                   ...                       ...                  ...
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                      1  ...          No      No                   No
# 1                      3  ...          No      Up                   No
# 2                      2  ...          No      No                   No
# 3                      2  ...          No      Up                   No
# 4                      1  ...          No  Steady                   No
# ...                  ...  ...         ...     ...                  ...
# 101761                 3  ...          No    Down                   No
# 101762                 5  ...          No  Steady                   No
# 101763                 1  ...          No    Down                   No
# 101764                10  ...          No      Up                   No
# 101765                 6  ...          No      No                   No
#
#         glipizide-metformin  glimepiride-pioglitazone  \
# 0                        No                        No
# 1                        No                        No
# 2                        No                        No
# 3                        No                        No
# 4                        No                        No
# ...                     ...                       ...
# 101761                   No                        No
# 101762                   No                        No
# 101763                   No                        No
# 101764                   No                        No
# 101765                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone  change diabetesMed  \
# 0                            No                      No      No          No
# 1                            No                      No      Ch         Yes
# 2                            No                      No      No         Yes
# 3                            No                      No      Ch         Yes
# 4                            No                      No      Ch         Yes
# ...                         ...                     ...     ...         ...
# 101761                       No                      No      Ch         Yes
# 101762                       No                      No      No         Yes
# 101763                       No                      No      Ch         Yes
# 101764                       No                      No      Ch         Yes
# 101765                       No                      No      No          No
#
#        readmitted
# 0              NO
# 1             >30
# 2              NO
# 3              NO
# 4              NO
# ...           ...
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [71518 rows x 50 columns]

# %% [markdown]
# ## 2) Missing Value

# %%
raw = raw[(raw != '?').all(axis=1)]
# Out:
# D:\anaconda\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
missing = pd.concat([raw.isnull().sum(), 100 * raw.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
# Out:
#                           count    %
# encounter_id                  0  0.0
# chlorpropamide                0  0.0
# glimepiride                   0  0.0
# acetohexamide                 0  0.0
# glipizide                     0  0.0
# glyburide                     0  0.0
# tolbutamide                   0  0.0
# pioglitazone                  0  0.0
# rosiglitazone                 0  0.0
# acarbose                      0  0.0
# miglitol                      0  0.0
# troglitazone                  0  0.0
# tolazamide                    0  0.0
# examide                       0  0.0
# citoglipton                   0  0.0
# insulin                       0  0.0
# glyburide-metformin           0  0.0
# glipizide-metformin           0  0.0
# glimepiride-pioglitazone      0  0.0
# metformin-rosiglitazone       0  0.0
# metformin-pioglitazone        0  0.0
# change                        0  0.0
# nateglinide                   0  0.0
# repaglinide                   0  0.0
# metformin                     0  0.0
# A1Cresult                     0  0.0
# patient_nbr                   0  0.0
# race                          0  0.0
# gender                        0  0.0
# age                           0  0.0
# weight                        0  0.0
# admission_type_id             0  0.0
# discharge_disposition_id      0  0.0
# admission_source_id           0  0.0
# time_in_hospital              0  0.0
# payer_code                    0  0.0
# diabetesMed                   0  0.0
# medical_specialty             0  0.0
# num_procedures                0  0.0
# num_medications               0  0.0
# number_outpatient             0  0.0
# number_emergency              0  0.0
# number_inpatient              0  0.0
# diag_1                        0  0.0
# diag_2                        0  0.0
# diag_3                        0  0.0
# number_diagnoses              0  0.0
# max_glu_serum                 0  0.0
# num_lab_procedures            0  0.0
# readmitted                    0  0.0

# %% [markdown]
# ## 3) Data Types

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1043 entries, 27068 to 101456
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   encounter_id              1043 non-null   int64
#  1   patient_nbr               1043 non-null   int64
#  2   race                      1043 non-null   object
#  3   gender                    1043 non-null   object
#  4   age                       1043 non-null   object
#  5   weight                    1043 non-null   object
#  6   admission_type_id         1043 non-null   int64
#  7   discharge_disposition_id  1043 non-null   int64
#  8   admission_source_id       1043 non-null   int64
#  9   time_in_hospital          1043 non-null   int64
#  10  payer_code                1043 non-null   object
#  11  medical_specialty         1043 non-null   object
#  12  num_lab_procedures        1043 non-null   int64
#  13  num_procedures            1043 non-null   int64
#  14  num_medications           1043 non-null   int64
#  15  number_outpatient         1043 non-null   int64
#  16  number_emergency          1043 non-null   int64
#  17  number_inpatient          1043 non-null   int64
#  18  diag_1                    1043 non-null   object
#  19  diag_2                    1043 non-null   object
#  20  diag_3                    1043 non-null   object
#  21  number_diagnoses          1043 non-null   int64
#  22  max_glu_serum             1043 non-null   object
#  23  A1Cresult                 1043 non-null   object
#  24  metformin                 1043 non-null   object
#  25  repaglinide               1043 non-null   object
#  26  nateglinide               1043 non-null   object
#  27  chlorpropamide            1043 non-null   object
#  28  glimepiride               1043 non-null   object
#  29  acetohexamide             1043 non-null   object
#  30  glipizide                 1043 non-null   object
#  31  glyburide                 1043 non-null   object
#  32  tolbutamide               1043 non-null   object
#  33  pioglitazone              1043 non-null   object
#  34  rosiglitazone             1043 non-null   object
#  35  acarbose                  1043 non-null   object
#  36  miglitol                  1043 non-null   object
#  37  troglitazone              1043 non-null   object
#  38  tolazamide                1043 non-null   object
#  39  examide                   1043 non-null   object
#  40  citoglipton               1043 non-null   object
#  41  insulin                   1043 non-null   object
#  42  glyburide-metformin       1043 non-null   object
#  43  glipizide-metformin       1043 non-null   object
#  44  glimepiride-pioglitazone  1043 non-null   object
#  45  metformin-rosiglitazone   1043 non-null   object
#  46  metformin-pioglitazone    1043 non-null   object
#  47  change                    1043 non-null   object
#  48  diabetesMed               1043 non-null   object
#  49  readmitted                1043 non-null   object
# dtypes: int64(13), object(37)
# memory usage: 415.6+ KB

# %%
raw['diag_2'].value_counts()
# Out:
# 428     86
# 427     68
# 401     61
# 424     48
# 414     48
#         ..
# E884     1
# 784      1
# 79       1
# E917     1
# 473      1
# Name: diag_2, Length: 210, dtype: int64

# %%
def drop_row(df,column,letter):
    df=df.reset_index(drop=True)
    for i in range(df.shape[0]):
        if df[column][i][0]==letter:
            df.drop(i,axis=0,inplace=True)
    return df

# %%
raw_data=drop_row(raw,'diag_2','E')
raw_data=drop_row(raw_data,'diag_2','V')
raw_data=drop_row(raw_data,'diag_3','E')
raw_data=drop_row(raw_data,'diag_2','V')

# %%
raw_data
# Out:
#      encounter_id  patient_nbr             race  gender      age     weight  \
# 0        88792836    100654011        Caucasian  Female  [70-80)   [75-100)
# 1        88986678     58682736        Caucasian    Male  [80-90)    [50-75)
# 2        89032962     69250302        Caucasian    Male  [60-70)  [100-125)
# 3        89191392     62022042        Caucasian    Male  [40-50)   [75-100)
# 4        89277516     30950811        Caucasian    Male  [50-60)  [100-125)
# ..            ...          ...              ...     ...      ...        ...
# 932     436721264    123812618  AfricanAmerican    Male  [70-80)   [75-100)
# 933     437928656    117516146        Caucasian    Male  [30-40)  [100-125)
# 934     437959022      8420319        Caucasian    Male  [60-70)  [100-125)
# 935     439577312     97708986        Caucasian  Female  [70-80)    [50-75)
# 936     439606454    113392368  AfricanAmerican    Male  [60-70)   [75-100)
#
#      admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                    3                         3                    1
# 1                    1                        11                    5
# 2                    1                         1                    7
# 3                    1                         3                    7
# 4                    3                         1                    1
# ..                 ...                       ...                  ...
# 932                  1                         1                    7
# 933                  1                         1                    7
# 934                  1                         1                    7
# 935                  1                         3                    7
# 936                  2                         1                    1
#
#      time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                  10  ...          No  Steady                   No
# 1                   6  ...          No  Steady                   No
# 2                   2  ...          No      No                   No
# 3                   3  ...          No      No                   No
# 4                   2  ...          No      No                   No
# ..                ...  ...         ...     ...                  ...
# 932                 1  ...          No  Steady                   No
# 933                 4  ...          No      No                   No
# 934                 3  ...          No      No                   No
# 935                13  ...          No      No                   No
# 936                 2  ...          No      No                   No
#
#      glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                     No                        No                       No
# 1                     No                        No                       No
# 2                     No                        No                       No
# 3                     No                        No                       No
# 4                     No                        No                       No
# ..                   ...                       ...                      ...
# 932                   No                        No                       No
# 933                   No                        No                       No
# 934                   No                        No                       No
# 935                   No                        No                       No
# 936                   No                        No                       No
#
#      metformin-pioglitazone  change diabetesMed readmitted
# 0                        No      Ch         Yes        <30
# 1                        No      No         Yes         NO
# 2                        No      No         Yes        >30
# 3                        No      No         Yes        >30
# 4                        No      No         Yes        >30
# ..                      ...     ...         ...        ...
# 932                      No      No         Yes         NO
# 933                      No      No          No         NO
# 934                      No      No         Yes         NO
# 935                      No      Ch         Yes         NO
# 936                      No      No          No        >30
#
# [937 rows x 50 columns]

# %%
def map_values(df):
    df['race'] = df['race'].map({'Other':1,
                                             'Hispanic':2, 
                                             'Caucasian':3,  
                                             'AfricanAmerican':4 ,
                                                'Asian':5})

    df['gender'] = df['gender'].map({'Female':1, 'Male':0})

    df['weight'] = df['weight'].map({'[0-10)':1,
                                               '[10-25)':2, 
                                               '[25-50)':3, 
                                               '[50-75)':4, 
                                               '[75-100)':5, 
                                               '[100-125)':6, 
                                               '[125-150)':7,  
                                               '[150-175)':8, 
                                               '[175-200)':9,
                                               '>200':10})
    df['age'] = df['age'].map({'[0-25)':1,
                                               '[10-20)':2, 
                                               '[20-30)':3, 
                                               '[30-40)':4, 
                                               '[40-50)':5, 
                                               '[50-60)':6, 
                                               '[60-70)':7,  
                                               '[70-80)':8, 
                                               '[80-90)':9,
                                               '[90-100)':10})

    df['payer_code'] = df['payer_code'].map({'BC':1, 
                                           'CH':2, 'CM':3, 'CP':4, 
                                           'DM':5, 'FR':6,
                                           'HM':7, 'MC':8,'MD':9,'MP':10,'OG':11,'OT':12,'PO':13,'SI':14,'SP':15,'UN':16,'WC':17})

    df['medical_specialty'] = df['medical_specialty'].map({'Urology':1, 'SurgicalSpecialty':2, 
                                                             'Surgery-Vascular':3, 'Surgery-Thoracic':4,
                                                            'Surgery-PlasticwithinHeadandNeck':5,
                                                             'Surgery-Plastic':6,'Surgery-Pediatric':7,
                                                            'Surgery-Pediatric':8,'Surgery-Maxillofacial':9,
                                                            'Surgery-General':10,'Surgery-Colon&Rectal':11,
                                                            'Surgery-Cardiovascular/Thoracic':12,
                                                            'Surgery-Cardiovascular':13,'Surgeon':14,
                                                            'SportsMedicine':15,'Speech':16,'Rheumatology':17,
                                                            'Resident':18,'Radiology':19,'Radiologist':20,
                                                            'Pulmonology':21,'Psychology':22,'Psychiatry-Child/Adolescent':23,
                                                            'Psychiatry-Addictive':24,'Psychiatry':25,
                                                            'Podiatry':26,'PhysicianNotFound':27,'PhysicalMedicineandRehabilitation':28,
                                                            'Perinatology':29,'Pediatrics-Pulmonology':30,'Pediatrics-Neurology':31,
                                                            'Pediatrics-InfectiousDiseases':32,'Pediatrics-Hematology-Oncology':33,
                                                            'Pediatrics-Endocrinology':34,'Pediatrics-EmergencyMedicine':35,
                                                            'Pediatrics-CriticalCare':36,'Pediatrics-AllergyandImmunology':37,
                                                            'Pediatrics':38,'Pathology':39,'OutreachServices':40,'Otolaryngology':41,
                                                            'Osteopath':42,'Orthopedics-Reconstructive':43,'Orthopedics':44,
                                                            'Ophthalmology':45,'Oncology':46,'ObstetricsandGynecology':47,
                                                            'Obstetrics':48,'Obsterics&Gynecology-GynecologicOnco':49,
                                                            'Neurophysiology':50,'Neurology':51,'Nephrology':52,'InternalMedicine':53,
                                                            'InfectiousDiseases':54,'Hospitalist':55,'Hematology/Oncology':56,
                                                            'Hematology':57,'Gynecology':58,'Gastroenterology':59,'Family/GeneralPractice':60,
                                                            'Endocrinology-Metabolism':61,'Endocrinology':62,'Emergency/Trauma':63,
                                                            'Dermatology':64,'Dentistry':65,'DCPTEAM':66,'Cardiology-Pediatric':67,
                                                            'Cardiology':68,'Anesthesiology-Pediatric':69,'Anesthesiology':70,
                                                            'AllergyandImmunology':71})

    df['max_glu_serum'] = df['max_glu_serum'].map({'None':1, 'Norm':2, '>200':3, '>300':4})

    df['A1Cresult'] = df['A1Cresult'].map({'None':1, 'Norm':2, '>7':3, '>8':4})

    df['metformin'] = df['metformin'].map({'No':1, 'Down':2, 'Steady':2, 'Up':3})

    df['repaglinide'] = df['repaglinide'].map({'No':1, 'Steady':2, 'Up':3})

    df['nateglinide'] = df['nateglinide'].map({'No':1, 'Steady':2, 'Up':3})

    df['chlorpropamide'] = df['chlorpropamide'].map({'No':1})

    df['glimepiride'] = df['glimepiride'].map({'No':1, 'Down':2, 'Steady':3, 'Up':4})

    df['acetohexamide'] = df['acetohexamide'].map({'No':1})

    df['glipizide'] = df['glipizide'].map({'No':1, 'Down':2, 'Steady':3, 'Up':4})

    df['glyburide'] = df['glyburide'].map({'No':1, 'Down':2, 'Steady':3, 'Up':4})

    df['tolbutamide'] = df['tolbutamide'].map({'No':1})

    df['pioglitazone'] = df['pioglitazone'].map({'No':1, 'Down':2, 'Steady':3, 'Up':4})

    df['rosiglitazone'] = df['rosiglitazone'].map({'No':1, 'Down':2, 'Steady':3, 'Up':4})

    df['acarbose'] = df['acarbose'].map({'No':1, 'Steady':2, 'Up':3})

    df['miglitol'] = df['miglitol'].map({'No':1, 'Steady':2})

    df['troglitazone'] = df['troglitazone'].map({'No':1})

    df['tolazamide'] = df['tolazamide'].map({'No':1, 'Steady':2})

    df['examide'] = df['examide'].map({'No':1})

    df['citoglipton'] = df['citoglipton'].map({'No':1})
    df['insulin'] = df['insulin'].map({'No':1, 'Down':2, 'Steady':2, 'Up':2})
    df['glyburide-metformin'] = df['glyburide-metformin'].map({'No':1, 'Down':2, 'Steady':2, 'Up':2})
    df['glipizide-metformin'] = df['glipizide-metformin'].map({'No':1,'Steady':2})
    df['glimepiride-pioglitazone'] = df['glimepiride-pioglitazone'].map({'No':1,'Steady':2})
    df['metformin-rosiglitazone'] = df['metformin-rosiglitazone'].map({'No':1,'Steady':2})
    df['metformin-pioglitazone'] = df['metformin-pioglitazone'].map({'No':1,'Steady':2})
    df['change'] = df['change'].map({'No':1,'Ch':2})
    df['diabetesMed'] = df['diabetesMed'].map({'No':1,'Yes':2})
    df['readmitted'] = df['readmitted'].map({'NO':1,'>30':2,'<30':3})
map_values(raw_data)

# %%
raw_data
# Out:
#      encounter_id  patient_nbr  race  gender  age  weight  admission_type_id  \
# 0        88792836    100654011     3       1    8     5.0                  3
# 1        88986678     58682736     3       0    9     4.0                  1
# 2        89032962     69250302     3       0    7     6.0                  1
# 3        89191392     62022042     3       0    5     5.0                  1
# 4        89277516     30950811     3       0    6     6.0                  3
# ..            ...          ...   ...     ...  ...     ...                ...
# 932     436721264    123812618     4       0    8     5.0                  1
# 933     437928656    117516146     3       0    4     6.0                  1
# 934     437959022      8420319     3       0    7     6.0                  1
# 935     439577312     97708986     3       1    8     4.0                  1
# 936     439606454    113392368     4       0    7     5.0                  2
#
#      discharge_disposition_id  admission_source_id  time_in_hospital  ...  \
# 0                           3                    1                10  ...
# 1                          11                    5                 6  ...
# 2                           1                    7                 2  ...
# 3                           3                    7                 3  ...
# 4                           1                    1                 2  ...
# ..                        ...                  ...               ...  ...
# 932                         1                    7                 1  ...
# 933                         1                    7                 4  ...
# 934                         1                    7                 3  ...
# 935                         3                    7                13  ...
# 936                         1                    1                 2  ...
#
#      citoglipton  insulin  glyburide-metformin  glipizide-metformin  \
# 0              1        2                    1                    1
# 1              1        2                    1                    1
# 2              1        1                    1                    1
# 3              1        1                    1                    1
# 4              1        1                    1                    1
# ..           ...      ...                  ...                  ...
# 932            1        2                    1                    1
# 933            1        1                    1                    1
# 934            1        1                    1                    1
# 935            1        1                    1                    1
# 936            1        1                    1                    1
#
#      glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                           1                        1
# 1                           1                        1
# 2                           1                        1
# 3                           1                        1
# 4                           1                        1
# ..                        ...                      ...
# 932                         1                        1
# 933                         1                        1
# 934                         1                        1
# 935                         1                        1
# 936                         1                        1
#
#      metformin-pioglitazone  change diabetesMed readmitted
# 0                         1       2           2          3
# 1                         1       1           2          1
# 2                         1       1           2          2
# 3                         1       1           2          2
# 4                         1       1           2          2
# ..                      ...     ...         ...        ...
# 932                       1       1           2          1
# 933                       1       1           1          1
# 934                       1       1           2          1
# 935                       1       2           2          1
# 936                       1       1           1          2
#
# [937 rows x 50 columns]

# %%
raw_data=raw_data.dropna()

# %%
import matplotlib.pyplot as plt
raw_data.hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5);

# %%
raw_data['readmitted'].hist(bins=3)
